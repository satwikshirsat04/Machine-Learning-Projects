# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
from datetime import datetime
end = datetime.now()
start = datetime(end.year-20,end.month,end.day)

# %%
stock = "GOOG"
google_data = yf.download(stock,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
google_data.head()
# Out:
# Price          Close      High       Low      Open      Volume M_Avg_100_days  \
# Ticker          GOOG      GOOG      GOOG      GOOG        GOOG
# Date
# 2005-01-28  4.723757  4.831962  4.624487  4.715815   490158373            NaN
# 2005-01-31  4.854795  4.873159  4.758006  4.806897   385306832            NaN
# 2005-02-01  4.762473  4.880605  4.730955  4.824020   756384528            NaN
# 2005-02-02  5.111406  5.380427  5.054326  5.349406  1316889593            NaN
# 2005-02-03  5.233012  5.295305  5.107684  5.112151   521471303            NaN
#
# Price      percent_change
# Ticker
# Date
# 2005-01-28            NaN
# 2005-01-31       0.027740
# 2005-02-01      -0.019017
# 2005-02-02       0.073267
# 2005-02-03       0.023791

# %%
google_data.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         GOOG         GOOG         GOOG         GOOG          GOOG
# count   5032.000000  5032.000000  5032.000000  5032.000000  5.032000e+03
# mean      49.211360    49.710079    48.698912    49.189778  1.076552e+08
# std       47.167721    47.662610    46.673020    47.136445  1.410883e+08
# min        4.342810     4.427437     4.282752     4.350503  1.584340e+05
# 25%       13.370910    13.503744    13.244031    13.382201  2.641700e+07
# 50%       28.252677    28.562057    27.995474    28.316236  4.971315e+07
# 75%       65.680380    66.145836    65.020999    65.392784  1.310704e+08
# max      201.899994   203.839996   199.783997   200.550003  1.650833e+09

# %%
google_data.shape
# Out:
# (5032, 7)

# %%
google_data.to_csv("google_stock_data.csv")

# %%
plt.figure(figsize=(15,4),)
plt.plot(google_data["Close"],label="Close Price")
plt.xlabel("years")
plt.ylabel("Close")
plt.grid=True
plt.legend()
plt.title("Close Price of GOOGLE Stock")
plt.show()

# %%
def plot_graph(value,column):
    plt.figure(figsize=(15,4))
    plt.plot(value)
    plt.xlabel("years")
    plt.ylabel("column")
    plt.legend()
    plt.title(f"{column} Price of GOOGLE Stock")
    plt.show()

# %%
for col in google_data.columns:
    plot_graph(google_data[col],col)

# %%
google_data
# Out:
# Price            Close        High         Low        Open      Volume
# Ticker            GOOG        GOOG        GOOG        GOOG        GOOG
# Date
# 2005-01-28    4.723757    4.831962    4.624487    4.715815   490158373
# 2005-01-31    4.854795    4.873159    4.758006    4.806897   385306832
# 2005-02-01    4.762473    4.880605    4.730955    4.824020   756384528
# 2005-02-02    5.111406    5.380427    5.054326    5.349406  1316889593
# 2005-02-03    5.233012    5.295305    5.107684    5.112151   521471303
# ...                ...         ...         ...         ...         ...
# 2025-01-22  200.029999  202.119995  199.199997  200.550003    15477400
# 2025-01-23  199.580002  201.940002  196.820007  199.979996    15170800
# 2025-01-24  201.899994  202.570007  199.783997  199.850006    12732400
# 2025-01-27  193.770004  198.669998  192.699997  194.190002    24915500
# 2025-01-28  196.110001  197.070007  192.610001  194.490005     6503712
#
# [5032 rows x 5 columns]

# %%
# google_data["M_Avg_100_days"] = google_data["Close"].rolling(100).mean()

# %%
google_data
# Out:
# Price            Close        High         Low        Open      Volume  \
# Ticker            GOOG        GOOG        GOOG        GOOG        GOOG
# Date
# 2005-01-28    4.723757    4.831962    4.624487    4.715815   490158373
# 2005-01-31    4.854795    4.873159    4.758006    4.806897   385306832
# 2005-02-01    4.762473    4.880605    4.730955    4.824020   756384528
# 2005-02-02    5.111406    5.380427    5.054326    5.349406  1316889593
# 2005-02-03    5.233012    5.295305    5.107684    5.112151   521471303
# ...                ...         ...         ...         ...         ...
# 2025-01-22  200.029999  202.119995  199.199997  200.550003    15477400
# 2025-01-23  199.580002  201.940002  196.820007  199.979996    15170800
# 2025-01-24  201.899994  202.570007  199.783997  199.850006    12732400
# 2025-01-27  193.770004  198.669998  192.699997  194.190002    24915500
# 2025-01-28  196.110001  197.070007  192.610001  194.490005     6503712
#
# Price      M_Avg_100_days
# Ticker
# Date
# 2005-01-28            NaN
# 2005-01-31            NaN
# 2005-02-01            NaN
# 2005-02-02            NaN
# 2005-02-03            NaN
# ...                   ...
# 2025-01-22     174.998202
# 2025-01-23     175.353026
# 2025-01-24     175.742023
# 2025-01-27     176.032663
# 2025-01-28     176.411543
#
# [5032 rows x 6 columns]

# %%
plot_graph(google_data['M_Avg_100_days'],"M_Avg_100_days")

# %%
plt.figure(figsize=(15,4),)
plt.plot(google_data['Close'],label="Close")
plt.plot(google_data['M_Avg_100_days'],label="M_Avg_100_days",color="r")
plt.xlabel("years")
plt.ylabel("Close")
plt.grid=True
plt.legend()
plt.title("Close Price & Mean Avg of GOOGLE Stock (100 Days Timestamps)")
plt.savefig("MA_100days vs Close",dpi=300)
plt.show()

# %%
# google_data["percent_change"] = google_data["Close"].pct_change()

# %%
google_data[["Close","percent_change"]]
# Out:
# Price            Close percent_change
# Ticker            GOOG
# Date
# 2005-01-28    4.723757            NaN
# 2005-01-31    4.854795       0.027740
# 2005-02-01    4.762473      -0.019017
# 2005-02-02    5.111406       0.073267
# 2005-02-03    5.233012       0.023791
# ...                ...            ...
# 2025-01-22  200.029999       0.002004
# 2025-01-23  199.580002      -0.002250
# 2025-01-24  201.899994       0.011624
# 2025-01-27  193.770004      -0.040267
# 2025-01-28  196.110001       0.012076
#
# [5032 rows x 2 columns]

# %%
plot_graph(google_data["percent_change"],"percent_change")

# %% [markdown]
# PRE PROCESS THE DATA

# %%
Adj_Close= google_data["Close"]
max(Adj_Close.values),min(Adj_Close.values)
# Out:
# (array([201.8999939]), array([4.34281015]))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(Adj_Close)
len(scaled_data)
# Out:
# 5032

# %%
x_data = []
y_data = []

for i in range(100,len(scaled_data)):
    x_data.append(scaled_data[i-100:i])
    y_data.append(scaled_data[i])

x_data,y_data = np.array(x_data), np.array(y_data)

# %%
print(x_data[0],y_data[0]) #100 Features and 1 Output
# Out:
# [[1.92828783e-03]
#  [2.59157545e-03]
#  [2.12426065e-03]
#  [3.89049974e-03]
#  [4.50604746e-03]
#  [3.68950890e-03]
#  [2.64307586e-03]
#  [2.97095314e-03]
#  [2.08406345e-03]
#  [1.63182200e-03]
#  [1.55896065e-03]
#  [2.26118796e-03]
#  [2.54257802e-03]
#  [2.94205673e-03]
#  [2.87799078e-03]
#  [2.88427114e-03]
#  [2.05767966e-03]
#  [2.38178680e-03]
#  [1.74613807e-03]
#  [1.36676280e-03]
#  [1.63307711e-03]
#  [1.39062913e-03]
#  [1.28008321e-03]
#  [1.50996805e-03]
#  [1.37053053e-03]
#  [1.73608515e-03]
#  [1.28259101e-03]
#  [7.98950165e-04]
#  [6.26848502e-04]
#  [3.52993900e-04]
#  [0.00000000e+00]
#  [4.54749252e-04]
#  [7.66266707e-05]
#  [5.40168910e-04]
#  [6.34383969e-04]
#  [7.39911882e-04]
#  [4.53494146e-04]
#  [5.01226815e-04]
#  [5.35146070e-04]
#  [8.07743152e-04]
#  [5.75343272e-04]
#  [6.85889198e-04]
#  [6.93427079e-04]
#  [6.34383969e-04]
#  [1.29389903e-03]
#  [1.70594087e-03]
#  [1.78759279e-03]
#  [2.35791323e-03]
#  [2.14310174e-03]
#  [2.29133706e-03]
#  [2.38303950e-03]
#  [2.25365249e-03]
#  [2.06772776e-03]
#  [1.25746715e-03]
#  [1.50494279e-03]
#  [2.06144981e-03]
#  [2.90311705e-03]
#  [3.67192052e-03]
#  [5.12787553e-03]
#  [6.09767467e-03]
#  [5.49720271e-03]
#  [5.62658972e-03]
#  [5.58513741e-03]
#  [5.65423103e-03]
#  [5.94190387e-03]
#  [6.43182990e-03]
#  [6.72201296e-03]
#  [6.53106780e-03]
#  [6.66171715e-03]
#  [6.41047378e-03]
#  [6.63407826e-03]
#  [7.07249906e-03]
#  [6.74965427e-03]
#  [6.81497532e-03]
#  [7.04234995e-03]
#  [7.30364624e-03]
#  [8.06114410e-03]
#  [8.06365431e-03]
#  [8.36891313e-03]
#  [1.01075206e-02]
#  [1.01766118e-02]
#  [1.07808515e-02]
#  [1.05786007e-02]
#  [1.14328262e-02]
#  [1.28485865e-02]
#  [1.41965033e-02]
#  [1.41839426e-02]
#  [1.32241964e-02]
#  [1.45658354e-02]
#  [1.48396875e-02]
#  [1.31362569e-02]
#  [1.39842021e-02]
#  [1.35055889e-02]
#  [1.35369955e-02]
#  [1.29842562e-02]
#  [1.25383024e-02]
#  [1.28699402e-02]
#  [1.32292168e-02]
#  [1.40331995e-02]
#  [1.41764072e-02]] [0.01435982]

# %%
len(x_data),len(y_data)  # -100 rows (5031 - 100)
# Out:
# (4932, 4932)

# %% [markdown]
# TRAIN TEST SPLIT

# %%
spliting_length = int(len(x_data)*0.70)

# %%
spliting_length
# Out:
# 3452

# %%
x_train = x_data[:spliting_length]
y_train = y_data[:spliting_length]

# %%
len(x_train)
# Out:
# 3452

# %%
x_test = x_data[spliting_length:]
y_test = y_data[spliting_length:]

# %%
len(x_test)
# Out:
# 1480

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3452, 100, 1)
# (3452, 1)
# (1480, 100, 1)
# (1480, 1)

# %% [markdown]
# TRAIN THE MODEL USING KERAS

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %%
model = Sequential()
model.add(LSTM(128,return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(64,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
model.fit(x_train,y_train,batch_size=16,epochs=10)
# Out:
# Epoch 1/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 11s 40ms/step - loss: 2.0405e-05
# Epoch 2/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 7.5714e-06
# Epoch 3/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 6.0933e-06
# Epoch 4/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 7.0851e-06
# Epoch 5/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 5.8614e-06
# Epoch 6/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 6.5837e-06
# Epoch 7/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 7.4408e-06
# Epoch 8/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - loss: 7.1162e-06
# Epoch 9/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 7.1631e-06
# Epoch 10/10
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - loss: 6.8791e-06

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 128)       │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 352,859 (1.35 MB)
#  Trainable params: 117,619 (459.45 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 235,240 (918.91 KB)

# %%
predictions = model.predict(x_test)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step

# %%
predictions
# Out:
# array([[0.27355182],
#        [0.2794632 ],
#        [0.2811183 ],
#        ...,
#        [0.96934247],
#        [0.9768737 ],
#        [0.945173  ]], dtype=float32)

# %%
inverse_pred = scaler.inverse_transform(predictions)
inverse_pred
# Out:
# array([[ 58.384937],
#        [ 59.552773],
#        [ 59.87975 ],
#        ...,
#        [195.84338 ],
#        [197.33122 ],
#        [191.06853 ]], dtype=float32)

# %%
inverse_y_test = scaler.inverse_transform(y_test)
inverse_y_test
# Out:
# array([[ 59.44639969],
#        [ 59.45238113],
#        [ 59.06527328],
#        ...,
#        [201.8999939 ],
#        [193.77000427],
#        [196.11000061]])

# %%
len(inverse_y_test)
# Out:
# 1480

# %% [markdown]
# ERROR RATE WITH MEAN SQUARE ERROR

# %%
mse = np.sqrt(np.mean((inverse_pred - inverse_y_test)**2))
mse
# Out:
# 2.4640505316171684

# %% [markdown]
# PLOTTING GRAPH BETWEEN ORIGINAL AND PREDICTED VALUES (TESTING DATASET)

# %%
ploting_data = pd.DataFrame(
    {
        "Original_Test_Data" : inverse_y_test.reshape(-1),
        "Predicted_Test_Data" : inverse_pred.reshape(-1)
    },
    index = google_data.index[spliting_length+100:]
)
ploting_data.head(10)
# Out:
#             Original_Test_Data  Predicted_Test_Data
# Date
# 2019-03-12           59.446400            58.384937
# 2019-03-13           59.452381            59.552773
# 2019-03-14           59.065273            59.879749
# 2019-03-15           59.010967            59.550064
# 2019-03-18           59.001003            59.303059
# 2019-03-19           59.727894            59.221851
# 2019-03-20           60.979397            59.778023
# 2019-03-21           61.356541            60.957863
# 2019-03-22           60.059204            61.637348
# 2019-03-25           59.436440            60.778126

# %%
plt.figure(figsize=(15,5))
plt.plot(ploting_data['Original_Test_Data'],label="Original Test_Data",color="r")
plt.plot(ploting_data['Predicted_Test_Data'],label="Predicted Test_Data",color="g")
plt.xlabel("years")
plt.ylabel("Close")
plt.grid=True
plt.legend()
plt.title("Original v/s Predictions Test Data (2.46% Error Rate)")
plt.savefig("Original vs Predictions(Test Data)",dpi=300)
plt.show()

# %%
plot_graph(pd.concat([Adj_Close[:spliting_length+100],ploting_data],axis=0),"Full Data")

# %%
plt.figure(figsize=(15,5))
plt.plot(Adj_Close[:spliting_length+100],label="Close Price")
plt.plot(ploting_data["Original_Test_Data"],label="Original Test Data")
plt.plot(ploting_data["Predicted_Test_Data"],label="Predicted Data")
plt.xlabel("years")
plt.ylabel("Close")
plt.grid=True
plt.legend()
plt.title("Original v/s Predictions Full Data (2.46% Error Rate)")
plt.savefig("Original vs Predictions(Full Data)",dpi=300)
plt.show()

# %%
model.save("stock_price_model.keras")
